# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# %%
def plot_surface(X, Y, Z, title="3D Shape", cmap=cm.viridis):
    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111, projection='3d')
    surf = ax.plot_surface(X, Y, Z, cmap=cmap, edgecolor='none', alpha=0.9)
    ax.set_title(title)
    ax.set_xlabel("X")
    ax.set_ylabel("Y")
    ax.set_zlabel("Z")
    plt.tight_layout()
    plt.show()

# %%
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)
u, v = np.meshgrid(u, v)

X = np.cos(u) * np.sin(v)
Y = np.sin(u) * np.sin(v)
Z = np.cos(v)

plot_surface(X, Y, Z, "🌍 Sphere")
# Out:
# /tmp/ipython-input-846209789.py:9: UserWarning: Glyph 127757 (\N{EARTH GLOBE EUROPE-AFRICA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127757 (\N{EARTH GLOBE EUROPE-AFRICA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
R = 1  # major radius
r = 0.3  # minor radius

u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, 2 * np.pi, 100)
u, v = np.meshgrid(u, v)

X = (R + r * np.cos(v)) * np.cos(u)
Y = (R + r * np.cos(v)) * np.sin(u)
Z = r * np.sin(v)

plot_surface(X, Y, Z, "🍩 Torus")
# Out:
# /tmp/ipython-input-846209789.py:9: UserWarning: Glyph 127849 (\N{DOUGHNUT}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127849 (\N{DOUGHNUT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
theta = np.linspace(0, 2 * np.pi, 150)
w = np.linspace(-0.3, 0.3, 30)
theta, w = np.meshgrid(theta, w)

R = 1
X = (R + w * np.cos(theta / 2)) * np.cos(theta)
Y = (R + w * np.cos(theta / 2)) * np.sin(theta)
Z = w * np.sin(theta / 2)

plot_surface(X, Y, Z, "♾️ Möbius Strip")

# %%
x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)
x, y = np.meshgrid(x, y)

z = x**2 - y**2

plot_surface(x, y, z, "🧪 Hyperbolic Paraboloid (Saddle)")
# Out:
# /tmp/ipython-input-846209789.py:9: UserWarning: Glyph 129514 (\N{TEST TUBE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129514 (\N{TEST TUBE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
u = np.linspace(-1.5, 1.5, 100)
v = np.linspace(-1.5, 1.5, 100)
u, v = np.meshgrid(u, v)

X = u - (u**3)/3 + u*v**2
Y = v - (v**3)/3 + v*u**2
Z = u**2 - v**2

plot_surface(X, Y, Z, "🧊 Enneper Surface")
# Out:
# /tmp/ipython-input-846209789.py:9: UserWarning: Glyph 129482 (\N{ICE CUBE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129482 (\N{ICE CUBE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, 2 * np.pi, 100)
u, v = np.meshgrid(u, v)

X = (np.cos(u) * (np.cos(u / 2) * (np.sqrt(2) - np.sin(v)) + np.sin(u / 2) * np.cos(v)))
Y = (np.sin(u) * (np.cos(u / 2) * (np.sqrt(2) - np.sin(v)) + np.sin(u / 2) * np.cos(v)))
Z = -np.sin(u / 2) * (np.sqrt(2) - np.sin(v)) + np.cos(u / 2) * np.cos(v)

plot_surface(X, Y, Z, "🧬 Klein Bottle Projection")
# Out:
# /tmp/ipython-input-846209789.py:9: UserWarning: Glyph 129516 (\N{DNA DOUBLE HELIX}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129516 (\N{DNA DOUBLE HELIX}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
u = np.linspace(0, 12*np.pi, 200)
v = np.linspace(0, 2*np.pi, 50)
u, v = np.meshgrid(u, v)

X = np.sin(u) * (np.exp(np.cos(u)) - 2 * np.cos(4*u) - np.sin(u/12)**5)
Y = np.cos(u) * (np.exp(np.cos(u)) - 2 * np.cos(4*u) - np.sin(u/12)**5)
Z = np.sin(v)

plot_surface(X, Y, Z, "🦋 Butterfly Curve Surface", cmap=cm.plasma)
# Out:
# /tmp/ipython-input-846209789.py:9: UserWarning: Glyph 129419 (\N{BUTTERFLY}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129419 (\N{BUTTERFLY}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
u = np.linspace(0, np.pi, 100)
v = np.linspace(0, 2*np.pi, 100)
u, v = np.meshgrid(u, v)

X = (np.cos(u) * np.sin(v)) / (1 + np.sin(u)**2)
Y = (np.sin(u) * np.sin(v)) / (1 + np.sin(u)**2)
Z = np.cos(v)

plot_surface(X, Y, Z, "😈 Boy's Surface Approximation")

# %%
u = np.linspace(0, np.pi, 100)
v = np.linspace(0, 2*np.pi, 100)
u, v = np.meshgrid(u, v)

X = np.sin(u) * np.cos(v)**2
Y = np.sin(u) * np.sin(v)**2
Z = np.cos(u) * np.sin(2*v)

plot_surface(X, Y, Z, "💠 Roman Surface")
# Out:
# /tmp/ipython-input-846209789.py:9: UserWarning: Glyph 128160 (\N{DIAMOND SHAPE WITH A DOT INSIDE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128160 (\N{DIAMOND SHAPE WITH A DOT INSIDE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(-1.5, 1.5, 100)
u, v = np.meshgrid(u, v)

a = 1
X = a * np.cosh(v) * np.cos(u)
Y = a * np.cosh(v) * np.sin(u)
Z = v

plot_surface(X, Y, Z, "➕ Catenoid (Minimal Surface)")
# Out:
# /tmp/ipython-input-846209789.py:9: UserWarning: Glyph 10133 (\N{HEAVY PLUS SIGN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 10133 (\N{HEAVY PLUS SIGN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
